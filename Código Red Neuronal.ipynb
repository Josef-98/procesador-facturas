# %%
# !apt-get -qq install -y poppler-utils
# !pip install --quiet --upgrade ultralytics
# Out:
# Selecting previously unselected package poppler-utils.
# (Reading database ... 126284 files and directories currently installed.)
# Preparing to unpack .../poppler-utils_22.02.0-2ubuntu0.9_amd64.deb ...
# Unpacking poppler-utils (22.02.0-2ubuntu0.9) ...
# Setting up poppler-utils (22.02.0-2ubuntu0.9) ...
# Processing triggers for man-db (2.10.2-1) ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 22.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 66.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 37.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 46.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.2 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# LUIS

import yaml
import pathlib
import sys

# 1. Define DATA_DIR como la carpeta que contiene images/, labels.txt y donde se escribirá invoice_data.yaml
DATA_DIR = pathlib.Path(
    "/content/drive/MyDrive/TFM UCM/3. Código/3.2 Redes/"
    "facturas/5. Facturas unificado"
)

# 2. Comprueba que labels.txt exista en DATA_DIR
labels_path = DATA_DIR / "labels.txt"
if not labels_path.exists():
    sys.exit(f"❌ No he encontrado labels.txt en:\n  {labels_path}")

# 3. Lee todas las etiquetas de labels.txt
with labels_path.open("r", encoding="utf-8") as f:
    labels = [line.strip() for line in f if line.strip()]

# 4. Construye el dict de nombres: {0: "Etiqueta0", 1: "Etiqueta1", …}
names_dict = {i: label for i, label in enumerate(labels)}

# 5. Monta el diccionario YAML
yaml_dict = {
    "path": str(DATA_DIR),
    "train": "images",
    "val": "images",
    "names": names_dict
}

# 6. Escribe invoice_data.yaml en la misma carpeta
yaml_path = DATA_DIR / "invoice_data.yaml"
with yaml_path.open("w", encoding="utf-8") as f:
    yaml.dump(yaml_dict, f, sort_keys=False, allow_unicode=True)

print("✅ YAML válido escrito en:", yaml_path)
print("--- contenido de invoice_data.yaml ---")
print(yaml_path.read_text(encoding="utf-8"))
# Out:
# ✅ YAML válido escrito en: /content/drive/MyDrive/TFM UCM/3. Código/3.2 Redes/facturas/5. Facturas unificado/invoice_data.yaml
# --- contenido de invoice_data.yaml ---
# path: /content/drive/MyDrive/TFM UCM/3. Código/3.2 Redes/facturas/5. Facturas unificado
# train: images
# val: images
# names:
#   0: Nombre del cliente
#   1: Primer apellido del cliente
#   2: Segundo apellido del cliente
#   3: Dirección del cliente
#   4: Numero de dirección del cliente
#   5: Codigo postal
#   6: Municipio
#   7: Ciudad
#   8: Telefono
#   9: Email
#   10: Num factura
#   11: Fecha factura
#   12: Referencia
#   13: Albarán
#   14: Descripción
#   15: Unidades
#   16: Precio
#   17: Total linea
#   18: Total bruto
#   19: Descuento
#   20: Portes
#   21: Base imponible
#   22: '% IVA'
#   23: Importe IVA
#   24: Total factura
#   25: Forma de pago
#   26: Codigo articulo

# %%
import glob, os

label_dir = "/ruta/a/labels"
for path in glob.glob(os.path.join(label_dir, "*.txt")):
    lines = []
    with open(path) as f:
        for l in f:
            parts = l.split()
            parts[0] = str(int(parts[0]) - 1)
            lines.append(" ".join(parts))
    with open(path, "w") as f:
        f.write("\n".join(lines) + "\n")

# %% [markdown]
# ### CÓDIGO DEFINITIVO NEURONA

# %%
# DAVID

# !yolo detect train \
  data="/content/drive/MyDrive/TFM UCM/3. Código/3.2 Redes/facturas/5. Facturas unificado/invoice_data.yaml" \
  model=yolov8m.pt \
  epochs=300 \
  imgsz=1280 \
  batch=4 \
  freeze=1 \
  lr0=0.0005 \
  lrf=0.1 \
  cos_lr=True \
  augment=True \
  auto_augment=randaugment \
  degrees=20 \
  translate=0.2 \
  scale=0.8 \
  shear=10 \
  perspective=0.002 \
  hsv_h=0.03 hsv_s=0.8 hsv_v=0.5 \
  mosaic=0.7 \
  mixup=0.5 \
  copy_paste=0.2 \
  rect=True \
  patience=60 \
  save_json=True \
  project="/content/drive/MyDrive/TFM UCM/3. Código/3.2 Redes/facturas/6. Resultado redes neuronales" \
  name="1. Red normal"
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# Ultralytics 8.3.172 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
from pathlib import Path

ruta = Path("/content/drive/MyDrive/TFM UCM/3. Código/3.2 Redes/facturas/5. Facturas unificado/invoice_data.yaml")
print("✅ Existe" if ruta.exists() else "❌ No existe")
# Out:
# ❌ No existe
